# %% [markdown]
# # Network science
#
# ## Structure of interactions and different models of ecological network
#
# Contributers: Nguyen Xuan Tung/ Farin Binta Zahir

# %% [markdown]
# ## Network comparison

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import collections
import itertools
import numpy as np
import community
import time
from numpy.linalg import eig
import seaborn as sns
import scipy.linalg as la3
import matplotlib.ticker as mtick

# %%
G1 = nx.read_edgelist('FW_001.txt', create_using=nx.DiGraph())
G2 = nx.read_edgelist('FW_002.txt', create_using=nx.DiGraph())
G3 = nx.read_edgelist('FW_003.txt', create_using=nx.DiGraph())
G4 = nx.read_edgelist('FW_004.txt', create_using=nx.DiGraph())
G5 = nx.read_edgelist('FW_005.txt', create_using=nx.DiGraph())
G6 = nx.read_edgelist('FW_006.txt', create_using=nx.DiGraph())
G7 = nx.read_edgelist('FW_007.txt', create_using=nx.DiGraph())
G8 = nx.read_edgelist('FW_008.txt', create_using=nx.DiGraph())

# %% [markdown]
# ### Degree centrality

# %%
x1 = nx.degree_centrality(G1)
x2 = nx.degree_centrality(G2)
x3 = nx.degree_centrality(G3)
x4 = nx.degree_centrality(G4)
x5 = nx.degree_centrality(G5)
x6 = nx.degree_centrality(G6)
x7 = nx.degree_centrality(G7)
x8 = nx.degree_centrality(G8)

# %%
fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

ax.plot(np.array(list(x1.values())).astype(float), label=f"FW_001")
ax.plot(np.array(list(x2.values())).astype(float), label=f"FW_002")
ax.plot(np.array(list(x3.values())).astype(float), label=f"FW_003")
ax.plot(np.array(list(x4.values())).astype(float), label=f"FW_004")
ax.plot(np.array(list(x5.values())).astype(float), label=f"FW_005")
ax.plot(np.array(list(x6.values())).astype(float), label=f"FW_006")
ax.plot(np.array(list(x7.values())).astype(float), label=f"FW_007")
ax.plot(np.array(list(x8.values())).astype(float), label=f"FW_008")
ax.tick_params(axis="both", which="major", labelsize=15)
ax.grid(True, which="both", linestyle=":")
ax.legend(fontsize=12, title="Food webs")
ax.set_title('Degree centralities comparision', fontsize = 25)
ax.set_xlabel("Number of species", fontsize=15)
ax.axis(xmin=0,xmax=45)
ax.set_ylabel("Degree centralities", fontsize=15)
# Out:
# Text(0, 0.5, 'Degree centralities')

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Eigenvactor centrality

# %%
x1 = nx.eigenvector_centrality(G1)
x2 = nx.eigenvector_centrality(G2)
x3 = nx.eigenvector_centrality(G3)
x4 = nx.eigenvector_centrality(G4)
x5 = nx.eigenvector_centrality(G5)
x6 = nx.eigenvector_centrality(G6)
x7 = nx.eigenvector_centrality(G7)
x8 = nx.eigenvector_centrality(G8)

# %%
fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

ax.plot(np.array(list(x1.values())).astype(float), label=f"FW_001")
ax.plot(np.array(list(x2.values())).astype(float), label=f"FW_002")
ax.plot(np.array(list(x3.values())).astype(float), label=f"FW_003")
ax.plot(np.array(list(x4.values())).astype(float), label=f"FW_004")
ax.plot(np.array(list(x5.values())).astype(float), label=f"FW_005")
ax.plot(np.array(list(x6.values())).astype(float), label=f"FW_006")
ax.plot(np.array(list(x7.values())).astype(float), label=f"FW_007")
ax.plot(np.array(list(x8.values())).astype(float), label=f"FW_008")
ax.tick_params(axis="both", which="major", labelsize=15)
ax.grid(True, which="both", linestyle=":")
ax.legend(fontsize=12, title="Food webs")
ax.set_title('Eigenvector centralities comparision', fontsize = 25)
ax.set_xlabel("Number of species", fontsize=15)
ax.axis(xmin=0,xmax=45)
ax.set_ylabel("Eigenvector centralities", fontsize=15)
# Out:
# Text(0, 0.5, 'Eigenvector centralities')

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Betweeness centrality

# %%
x1 = nx.betweenness_centrality(G1)
x2 = nx.betweenness_centrality(G2)
x3 = nx.betweenness_centrality(G3)
x4 = nx.betweenness_centrality(G4)
x5 = nx.betweenness_centrality(G5)
x6 = nx.betweenness_centrality(G6)
x7 = nx.betweenness_centrality(G7)
x8 = nx.betweenness_centrality(G8)

# %%
fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

ax.plot(np.array(list(x1.values())).astype(float), label=f"FW_001")
ax.plot(np.array(list(x2.values())).astype(float), label=f"FW_002")
ax.plot(np.array(list(x3.values())).astype(float), label=f"FW_003")
ax.plot(np.array(list(x4.values())).astype(float), label=f"FW_004")
ax.plot(np.array(list(x5.values())).astype(float), label=f"FW_005")
ax.plot(np.array(list(x6.values())).astype(float), label=f"FW_006")
ax.plot(np.array(list(x7.values())).astype(float), label=f"FW_007")
ax.plot(np.array(list(x8.values())).astype(float), label=f"FW_008")
ax.tick_params(axis="both", which="major", labelsize=15)
ax.grid(True, which="both", linestyle=":")
ax.legend(fontsize=12, title="Food webs")
ax.set_title('Betweeness centralities comparision', fontsize = 25)
ax.set_xlabel("Number of species", fontsize=15)
ax.axis(xmin=0,xmax=35)
ax.set_ylabel("Betweeness centralities", fontsize=15)
# Out:
# Text(0, 0.5, 'Betweeness centralities')

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Closeness centrality

# %%
x1 = nx.closeness_centrality(G1)
x2 = nx.closeness_centrality(G2)
x3 = nx.closeness_centrality(G3)
x4 = nx.closeness_centrality(G4)
x5 = nx.closeness_centrality(G5)
x6 = nx.closeness_centrality(G6)
x7 = nx.closeness_centrality(G7)
x8 = nx.closeness_centrality(G8)

# %%
fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

ax.plot(np.array(list(x1.values())).astype(float), label=f"FW_001")
ax.plot(np.array(list(x2.values())).astype(float), label=f"FW_002")
ax.plot(np.array(list(x3.values())).astype(float), label=f"FW_003")
ax.plot(np.array(list(x4.values())).astype(float), label=f"FW_004")
ax.plot(np.array(list(x5.values())).astype(float), label=f"FW_005")
ax.plot(np.array(list(x6.values())).astype(float), label=f"FW_006")
ax.plot(np.array(list(x7.values())).astype(float), label=f"FW_007")
ax.plot(np.array(list(x8.values())).astype(float), label=f"FW_008")
ax.tick_params(axis="both", which="major", labelsize=15)
ax.grid(True, which="both", linestyle=":")
ax.legend(fontsize=12, title="Food webs")
ax.set_title('Closeness centralities comparision', fontsize = 25)
ax.set_xlabel("Number of species", fontsize=15)
ax.set_ylabel("Closeness centralities", fontsize=15)
ax.axis(xmin=0,xmax=45)
# Out:
# (0.0, 45.0, -0.035504201680672275, 0.7455882352941177)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Motif

# %%
motifs = {
    'S1': nx.DiGraph([(1,2),(2,3)]),
    'S2': nx.DiGraph([(1,2),(1,3),(2,3)]),
    'S3': nx.DiGraph([(1,2),(2,3),(3,1)]),
    'S4': nx.DiGraph([(1,2),(3,2)]),
    'S5': nx.DiGraph([(1,2),(1,3)])
    }

# %%
def mcounter(gr, mo):
    """Counts motifs in a directed graph
    :param gr: A ``DiGraph`` object
    :param mo: A ``dict`` of motifs to count
    :returns: A ``dict`` with the number of each motifs, with the same keys as ``mo``
    This function is actually rather simple. It will extract all 3-grams from
    the original graph, and look for isomorphisms in the motifs contained
    in a dictionary. The returned object is a ``dict`` with the number of
    times each motif was found.::
        >>> print mcounter(gr, mo)
        {'S1': 4, 'S3': 0, 'S2': 1, 'S5': 0, 'S4': 3}
    """
    #This function will take each possible subgraphs of gr of size 3, then
    #compare them to the mo dict using .subgraph() and is_isomorphic
    
    #This line simply creates a dictionary with 0 for all values, and the
    #motif names as keys

    mcount = dict(zip(mo.keys(), list(map(int, np.zeros(len(mo))))))
    nodes = gr.nodes()

    #The for each each of the triplets, we (i) take its subgraph, and compare
    #it to all fo the possible motifs
    for trip in itertools.combinations(nodes(),3):
        subg = gr.subgraph(trip)
        for keys in mo.keys():
            if nx.is_isomorphic(subg, mo[keys]):
                mcount[keys] += 1
        
    return mcount

# %%
mcounter(G1, motifs)
# Out:
# {'S1': 199, 'S2': 31, 'S3': 3, 'S4': 274, 'S5': 151}

# %%
mcounter(G2, motifs)
# Out:
# {'S1': 3, 'S2': 4, 'S3': 0, 'S4': 12, 'S5': 6}

# %%
mcounter(G3, motifs)
# Out:
# {'S1': 112, 'S2': 24, 'S3': 7, 'S4': 92, 'S5': 62}

# %%
mcounter(G4, motifs)
# Out:
# {'S1': 81, 'S2': 27, 'S3': 0, 'S4': 123, 'S5': 96}

# %%
mcounter(G5, motifs)
# Out:
# {'S1': 239, 'S2': 113, 'S3': 9, 'S4': 289, 'S5': 202}

# %%
mcounter(G6, motifs)
# Out:
# {'S1': 166, 'S2': 109, 'S3': 10, 'S4': 141, 'S5': 228}

# %%
mcounter(G7, motifs)
# Out:
# {'S1': 241, 'S2': 68, 'S3': 2, 'S4': 259, 'S5': 213}

# %% [raw]
# mcounter(G8, motifs)

# %%
ans1 = {'S1': 199, 'S2': 31, 'S3': 3, 'S4': 274, 'S5': 151}
ans2 = {'S1': 3, 'S2': 4, 'S3': 0, 'S4': 12, 'S5': 6}
ans3 = {'S1': 112, 'S2': 24, 'S3': 7, 'S4': 92, 'S5': 62}
ans4 = {'S1': 81, 'S2': 27, 'S3': 0, 'S4': 123, 'S5': 96}
ans5 = {'S1': 239, 'S2': 113, 'S3': 9, 'S4': 289, 'S5': 202}
ans6 = {'S1': 166, 'S2': 109, 'S3': 10, 'S4': 141, 'S5': 228}
ans7 = {'S1': 241, 'S2': 68, 'S3': 2, 'S4': 259, 'S5': 213}
ans8 = {'S1': 10351, 'S2': 3671, 'S3': 44, 'S4': 26442, 'S5': 67971}

# %%
result = pd.read_csv("motif.csv")
colors_list = ['#A52A2A','#FF9912','#006400','#00EEEE', '#A9A9A9']
FW = ['FW_001', 'FW_002','FW_003','FW_004','FW_005','FW_006','FW_007','FW_008']

# Normalize result
result_pct = result.div(result.sum(1), axis=0)

ax = result_pct.plot(kind='bar',figsize=(15,5),width = 0.8,color = colors_list,edgecolor=None)
plt.legend(labels=result.columns,fontsize= 14, bbox_to_anchor=(1.04, 1), loc="upper left")
plt.title("Food web motif comparision",fontsize= 25)
plt.xlabel('Food Networks',fontsize= 20)

plt.xticks(fontsize=14)
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.yticks([])

# Add this loop to add the annotations
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.0%}', (x + width/2, y + height*1.02), ha='center')

x = np.arange(len(FW))  # the label locations
width = 0.1  # the width of the bars
ax.set_xticklabels(FW)
ax.legend(fontsize=12, title="Food webs")
plt.xticks(rotation=18360)
plt.savefig('motifFW.png')

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %%
def generate_random(s,c): 
    np.random.seed(1234)
    temp = np.zeros((s,s))
    p = np.random.uniform(0,1,s*s)
    mask = (p <= c).reshape(s,s)
    temp[mask] = 1
    rowsum = temp.sum(axis = 1)
    colsum = temp.sum(axis = 0)
    mask = (rowsum + colsum) == 0
    temp = temp[~mask][:,~mask]
    return temp.astype(int)

def generate_cascade(s,c):
    np.random.seed(1234)
    m = np.zeros((s,s))
    p = 2*c*s/(s-1)
    pc = np.random.uniform(0,1, size = s)
    m[:, pc < p] = 1
    m = np.triu(m, k = 1)
    rowsum = m.sum(axis = 1)
    colsum = m.sum(axis = 0)
    mask = (rowsum + colsum) == 0
    m = m[~mask][:,~mask]
    return m.astype('int') # since m is a binary matrix of zeros and ones it is sufficient to have int as type of the ndarray
    # in this way we select only those elements in the upper triangle matrix wrt m by also prohibiting self loops (k is greater than zero)


def generate_niche(s,c):
    np.random.seed(1234)
    dataframe = pd.DataFrame(np.zeros((s,s))) 
    dataframe.columns = np.arange(s) + 1
    dataframe.set_index(dataframe.columns)

    # we then substitute columns names and indices with niche values np.random.uniform(0, 1)
    ni = np.random.uniform(0, 1, size = s)

    dataframe = dataframe.set_index(ni)
    dataframe.columns = ni
    y = np.random.uniform(0, 1, size = s)
    ri = ni*(1 - (1 - y)**(2*c/(1-2*c)))
    ci = np.random.uniform(ri/2, ni)
    lower_bound = ci - ri/2
    upper_bound = ci + ri/2
    dataframe[((dataframe.index > lower_bound[:,None]).T)*((dataframe.index < upper_bound[:,None]).T)] = 1
    n = np.array(dataframe)
    rowsum = n.sum(axis = 1)
    colsum = n.sum(axis = 0)
    mask = (rowsum + colsum) == 0
    n = n[~mask][:,~mask]
    return n.astype('int')

def generate_nested(s,c, check = False):
    np.random.seed(1234)
    dataframe = pd.DataFrame(np.zeros((s,s)))#, index = np.arange(5) + 1) 
    ni = np.random.uniform(0, 1, size = s)
    dataframe = dataframe.set_index(ni)
    dataframe.columns = ni
    dataframe.columns = dataframe.columns.sort_values() 
    dataframe = dataframe.set_index(dataframe.columns)
    y = np.random.uniform(0, 1, size = s)
    ri = ni*(1 - (1 - y)**(2*c/(1-2*c)))
    ri /= np.sum(ri)
    ri = (ri*s*s*c).astype(int)
    ri[0] = 0 # in order to have at least a basal species
    ri[ri > s-1] = s-1
    for i in range(s):
        while dataframe[dataframe.columns[i]].sum() < ri[i]:
            randomprey = np.random.randint(i+1) # 1
            dataframe[dataframe.columns[i]].iloc[randomprey] = 1
            if dataframe.iloc[randomprey].sum() == 1: # 2 
                True
            elif dataframe[dataframe.columns[i]].sum() < ri[i]: 
                try: 
                    a = np.random.choice(dataframe[dataframe.columns[dataframe.iloc[randomprey] != 0]].columns)
                    randomprey1 = np.random.choice(dataframe[dataframe[a] != 0].index)
                    dataframe[dataframe.columns[i]].loc[randomprey1] = 1
                except: continue
            if (dataframe[dataframe.columns[i]].sum() < ri[i]) and (dataframe.iloc[randomprey].sum() == 1):
                randomprey0 = np.random.randint(i,s)
                dataframe[dataframe.columns[i]].iloc[randomprey0] = 1
            elif (dataframe[dataframe.columns[i]].sum() < ri[i]) and (dataframe.iloc[randomprey].sum() != 1):
                randomprey2 = np.random.randint(i,s) 
                dataframe[dataframe.columns[i]].iloc[randomprey2] = 1
    if (dataframe.sum().sum() == sum(ri)) and check == True: print("sanity check")
    dataframe.iloc[s-1][dataframe.columns[:-1]] = np.zeros(s-1) # in order to have at least a top species
    n = np.array(dataframe)
    return n.astype(int)

# %%
random1 = generate_random(40,0.237)
random2 = generate_random(14,0.418)
random3 = generate_random(28,0.336)
random4 = generate_random(32,0.282)
random5 = generate_random(44,0.437)
random6 = generate_random(30,0.526)
random7 = generate_random(48,0.196)
random8 = generate_random(249,0.107)

# %%
random1 = nx.trophic_differences(nx.DiGraph(random1))
random2 = nx.trophic_differences(nx.DiGraph(random2))
random3 = nx.trophic_differences(nx.DiGraph(random3))
random4 = nx.trophic_differences(nx.DiGraph(random4))
random5 = nx.trophic_differences(nx.DiGraph(random5))
random6 = nx.trophic_differences(nx.DiGraph(random6))
random7 = nx.trophic_differences(nx.DiGraph(random7))
random8 = nx.trophic_differences(nx.DiGraph(random8))


fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

ax.plot(np.array(list(random1.values())).astype(float), label=f"FW_001")
ax.plot(np.array(list(random2.values())).astype(float), label=f"FW_002")
ax.plot(np.array(list(random3.values())).astype(float), label=f"FW_003")
ax.plot(np.array(list(random4.values())).astype(float), label=f"FW_004")
ax.plot(np.array(list(random5.values())).astype(float), label=f"FW_005")
ax.plot(np.array(list(random6.values())).astype(float), label=f"FW_006")
ax.plot(np.array(list(random7.values())).astype(float), label=f"FW_007")
ax.plot(np.array(list(random8.values())).astype(float), label=f"FW_008")
ax.tick_params(axis="both", which="major", labelsize=15)
ax.grid(True, which="both", linestyle=":")
ax.legend(fontsize=12, title="Food webs")
ax.set_title('Degree centralities comparision', fontsize = 25)
ax.set_xlabel("Number of species", fontsize=15)
ax.axis(xmin=0,xmax=45)
ax.set_ylabel("Degree centralities", fontsize=15)
# Out:
# Text(0, 0.5, 'Degree centralities')

# %%
cascade1 = generate_cascade(40,0.237)
cascade2 = generate_cascade(14,0.418)
cascade3 = generate_cascade(28,0.336)
cascade4 = generate_cascade(32,0.282)
cascade5 = generate_cascade(44,0.437)
cascade6 = generate_cascade(30,0.526)
cascade7 = generate_cascade(48,0.196)
cascade8 = generate_cascade(249,0.107)

# %%
cascade1 = nx.trophic_differences(nx.DiGraph(cascade1))
cascade2 = nx.trophic_differences(nx.DiGraph(cascade2))
cascade3 = nx.trophic_differences(nx.DiGraph(cascade3))
cascade4 = nx.trophic_differences(nx.DiGraph(cascade4))
cascade5 = nx.trophic_differences(nx.DiGraph(cascade5))
cascade6 = nx.trophic_differences(nx.DiGraph(cascade6))
cascade7 = nx.trophic_differences(nx.DiGraph(cascade7))
cascade8 = nx.trophic_differences(nx.DiGraph(cascade8))


fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

ax.plot(np.array(list(cascade1.values())).astype(float), label=f"FW_001")
ax.plot(np.array(list(cascade2.values())).astype(float), label=f"FW_002")
ax.plot(np.array(list(cascade3.values())).astype(float), label=f"FW_003")
ax.plot(np.array(list(cascade4.values())).astype(float), label=f"FW_004")
ax.plot(np.array(list(cascade5.values())).astype(float), label=f"FW_005")
ax.plot(np.array(list(cascade6.values())).astype(float), label=f"FW_006")
ax.plot(np.array(list(cascade7.values())).astype(float), label=f"FW_007")
ax.plot(np.array(list(cascade8.values())).astype(float), label=f"FW_008")
ax.tick_params(axis="both", which="major", labelsize=15)
ax.grid(True, which="both", linestyle=":")
ax.legend(fontsize=12, title="Food webs")
ax.set_title('Degree centralities comparision', fontsize = 25)
ax.set_xlabel("Number of species", fontsize=15)
ax.axis(xmin=0,xmax=45)
ax.set_ylabel("Degree centralities", fontsize=15)
# Out:
# Text(0, 0.5, 'Degree centralities')

# %%
niche1 = generate_niche(40,0.237)
niche2 = generate_niche(14,0.418)
niche3 = generate_niche(28,0.336)
niche4 = generate_niche(32,0.282)
niche5 = generate_niche(44,0.437)
niche6 = generate_niche(30,0.526)
niche7 = generate_niche(48,0.196)
niche8 = generate_niche(249,0.107)

# %%
niche1 = nx.trophic_differences(nx.DiGraph(niche1))
niche2 = nx.trophic_differences(nx.DiGraph(niche2))
niche3 = nx.trophic_differences(nx.DiGraph(niche3))
niche4 = nx.trophic_differences(nx.DiGraph(niche4))
niche5 = nx.trophic_differences(nx.DiGraph(niche5))
niche6 = nx.trophic_differences(nx.DiGraph(niche6))
niche7 = nx.trophic_differences(nx.DiGraph(niche7))
niche8 = nx.trophic_differences(nx.DiGraph(niche8))


fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

ax.plot(np.array(list(niche1.values())).astype(float), label=f"FW_001")
ax.plot(np.array(list(niche2.values())).astype(float), label=f"FW_002")
ax.plot(np.array(list(niche3.values())).astype(float), label=f"FW_003")
ax.plot(np.array(list(niche4.values())).astype(float), label=f"FW_004")
ax.plot(np.array(list(niche5.values())).astype(float), label=f"FW_005")
ax.plot(np.array(list(niche6.values())).astype(float), label=f"FW_006")
ax.plot(np.array(list(niche7.values())).astype(float), label=f"FW_007")
ax.plot(np.array(list(niche8.values())).astype(float), label=f"FW_008")
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~\lib\site-packages\networkx\algorithms\centrality\trophic.py in trophic_levels(G, weight)
#      60     try:
# ---> 61         n = np.linalg.inv(i - p)
#      62     except np.linalg.LinAlgError as err:
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# ~\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     545     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 546     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     547     return wrap(ainv.astype(result_t, copy=False))
#
# ~\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#
# LinAlgError: Singular matrix
#
# ...

# %%
niche1 = generate_nested(40,0.237)
niche2 = generate_nested(14,0.418)
niche3 = generate_nested(28,0.336)
niche4 = generate_nested(32,0.282)
niche5 = generate_nested(44,0.437)
niche6 = generate_nested(30,0.526)
niche7 = generate_nested(48,0.196)
niche8 = generate_nested(249,0.107)

# %%
niche1 = nx.trophic_differences(nx.DiGraph(niche1))
niche2 = nx.trophic_differences(nx.DiGraph(niche2))
niche3 = nx.trophic_differences(nx.DiGraph(niche3))
niche4 = nx.trophic_differences(nx.DiGraph(niche4))
niche5 = nx.trophic_differences(nx.DiGraph(niche5))
niche6 = nx.trophic_differences(nx.DiGraph(niche6))
niche7 = nx.trophic_differences(nx.DiGraph(niche7))
niche8 = nx.trophic_differences(nx.DiGraph(niche8))


fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

ax.plot(np.array(list(niche1.values())).astype(float), label=f"FW_001")
ax.plot(np.array(list(niche2.values())).astype(float), label=f"FW_002")
ax.plot(np.array(list(niche3.values())).astype(float), label=f"FW_003")
ax.plot(np.array(list(niche4.values())).astype(float), label=f"FW_004")
ax.plot(np.array(list(niche5.values())).astype(float), label=f"FW_005")
ax.plot(np.array(list(niche6.values())).astype(float), label=f"FW_006")
ax.plot(np.array(list(niche7.values())).astype(float), label=f"FW_007")
ax.plot(np.array(list(niche8.values())).astype(float), label=f"FW_008")
ax.tick_params(axis="both", which="major", labelsize=15)
ax.grid(True, which="both", linestyle=":")
ax.legend(fontsize=12, title="Food webs")
ax.set_title('Degree centralities comparision', fontsize = 25)
ax.set_xlabel("Number of species", fontsize=15)
ax.axis(xmin=0,xmax=45)
ax.set_ylabel("Degree centralities", fontsize=15)
# Out:
# Text(0, 0.5, 'Degree centralities')
